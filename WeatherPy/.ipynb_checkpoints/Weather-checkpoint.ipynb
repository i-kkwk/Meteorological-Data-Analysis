# %%
#Dependencies

import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
import json
import time

from weather_api import api_key

from citipy import citipy

# %%
#Import data
data = "../output_data/cities.csv"
cities = pd.read_csv(data)
cities = cities.set_index("City")

cities
# Out:
#              City_ID  Cloudiness Country        Date  Humidity    Lat     Lng  \
# City
# ostrovnoy          0           2      RU  1558378754        72  68.05   39.51
# mahebourg          1          75      MU  1558378503        74 -20.41   57.70
# qaanaaq            2          25      GL  1558378755        73  77.48  -69.36
# zhuhai             3           0      CN  1558378755        39  40.71  112.04
# cape town          4          20      ZA  1558378755        76 -33.93   18.42
# ...              ...         ...     ...         ...       ...    ...     ...
# yabrud           543           0      SY  1558378840        32  33.97   36.66
# paraiso          544           5      MX  1558378898         4  24.01 -104.61
# veraval          545           0      FR  1558378898        62  49.65    0.71
# novyy urgal      546         100      RU  1558378899        93  51.07  132.56
# tongren          547           4      CN  1558378899        64  27.72  109.18
#
#              Max Temp  Wind Speed
# City
# ostrovnoy       37.50        7.16
# mahebourg       78.80       11.41
# qaanaaq         22.20        2.37
# zhuhai          44.60        4.47
# cape town       55.99        8.05
# ...               ...         ...
# yabrud          80.60        8.05
# paraiso         84.20       16.11
# veraval         61.00        8.05
# novyy urgal     49.74        2.68
# tongren         55.86        2.84
#
# [548 rows x 9 columns]

# %% [markdown]
# ## Generate Cities List

# %%
#Range Latitud/Longitude and create list to hold both of it. 

latitude = (-90, 90)
longitude =(-180, 180)
lat_lng = []

#Create list to hold cities.
cities = []

#Crete set of Latitude and Longitude with random.
lat = np.random.uniform(latitude[0], latitude[1], size = 1500)
lng = np.random.uniform(longitude[0], longitude[1], size=1500)

lat_lng = zip(lat, lng)

#Generate cities list.
for lat_lngs in lat_lng:
    city = citipy.nearest_city(lat_lngs[0], lat_lngs[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 604

# %%
#Check cities list.
print(cities)
# Out:
# ['pochinki', 'rikitea', 'udhampur', 'kruisfontein', 'san cristobal', 'thompson', 'portree', 'daloa', 'port alfred', 'koslan', 'lavrentiya', 'gazli', 'albany', 'cayenne', 'dikson', 'nanchang', 'dhidhdhoo', 'comodoro rivadavia', 'te anau', 'saskylakh', 'kapaa', 'avarua', 'arraial do cabo', 'polignano a mare', 'khatanga', 'caravelas', 'half moon bay', 'cape town', 'ribeira grande', 'atuona', 'longyearbyen', 'ust-kamchatsk', 'lucea', 'ahipara', 'punta arenas', 'vestbygda', 'kudahuvadhoo', 'filingue', 'qaanaaq', 'saint-joseph', 'bluff', 'yellowknife', 'hualmay', 'pierre', 'chokurdakh', 'belushya guba', 'hamilton', 'san patricio', 'flinders', 'sentyabrskiy', 'narsaq', 'busselton', 'tadine', 'lebu', 'new norfolk', 'georgetown', 'mattru', 'hilo', 'mahebourg', 'alihe', 'otjimbingwe', 'pangai', 'aswan', 'foam lake', 'bredasdorp', 'hermanus', 'pacific grove', 'port hardy', 'tiznit', 'guerrero negro', 'mikhaylovka', 'hambantota', 'redlands', 'monte patria', 'mercedes', 'asau', 'touros', 'pangoa', 'sistranda', 'antalaha', 'tuatapere', 'de aar', 'ushuaia', 'butaritari', 'luderitz', 'alofi', 'illoqqortoormiut', 'troyes', 'taoudenni', 'morros', 'samarai', 'souillac', 'barrow', 'toora-khem', 'mataura', 'jutai', 'whitehorse', 'hithadhoo', 'clyde river', 'shingu', 'morondava', 'emba', 'vanimo', 'nikolskoye', 'padang', 'ponta do sol', 'upernavik', 'luanda', 'tiksi', 'phan thiet', 'akkermanovka', 'sao filipe', 'husavik', 'floro', 'hobart', 'qax', 'sinnamary', 'itarema', 'jamestown', 'lilongwe', 'vostok', 'mogok', 'pringsewu', 'san matias', 'abeche', 'klaksvik', 'katsuura', 'saleaula', 'hyeres', 'takoradi', 'korla', 'raga', 'mar del plata', 'puerto ayora', 'najran', 'vaini', 'buraydah', 'santa isabel do rio negro', 'coari', 'norman wells', 'dunedin', 'grand-santi', 'saint-augustin', 'tasiilaq', 'faanui', 'plastun', 'ngukurr', 'yumen', 'bairiki', 'barcelos', 'zhuhai', 'fuerte olimpo', 'bethel', 'leningradskiy', 'pangnirtung', 'bima', 'amderma', 'los llanos de aridane', 'innisfail', 'saldanha', 'nalut', 'carnarvon', 'peniche', 'bambous virieux', 'naze', 'lorengau', 'mugur-aksy', 'tengzhou', 'yulara', 'araouane', 'cap malheureux', 'jumla', 'hasaki', 'alice springs', 'mehamn', 'jamame', 'barentsburg', 'pevek', 'waipawa', 'maniitsoq', 'potosi', 'chirongui', 'lagoa', 'maneadero', 'namatanai', 'cururupu', 'port elizabeth', 'katobu', 'tuapse', 'ouadda', 'ozernovskiy', 'buala', 'olafsvik', 'marsabit', 'esperance', 'codrington', 'port hedland', 'killybegs', 'camaqua', 'antropovo', 'chaiyaphum', 'aquiraz', 'barra de sao francisco', 'iskateley', 'stokmarknes', 'nelson bay', 'ketchikan', 'tazovskiy', 'boa vista', 'fuxin', 'umzimvubu', 'iranshahr', 'salekhard', 'umm lajj', 'natchitoches', 'cerrito', 'puerto quijarro', 'shitanjing', 'taolanaro', 'tsihombe', 'teahupoo', 'boyolangu', 'castro', 'saint-michel-des-saints', 'uyuni', 'mentok', 'bunbury', 'cidreira', 'cabugao', 'jam sahib', 'ulladulla', 'aldan', 'fortuna', 'mys shmidta', 'hopelchen', 'beringovskiy', 'kodiak', 'erdenet', 'mora', 'whitefish', 'springfield', 'mancio lima', 'ucluelet', 'turukhansk', 'shenjiamen', 'broken hill', 'kamenka', 'bay roberts', 'east london', 'bengkulu', 'saint-philippe', 'sabzevar', 'mendoza', 'nizwa', 'saint george', 'tuktoyaktuk', 'kuusamo', 'batemans bay', 'nizhniy kuranakh', 'sorvag', 'vardo', 'makakilo city', 'prince rupert', 'fukue', 'ambilobe', 'niceville', 'kieta', 'attawapiskat', 'coquimbo', 'bukachacha', 'amga', 'palabuhanratu', 'wagar', 'huangnihe', 'orange', 'karratha', 'kailua', 'sawtell', 'nioro', 'saint anthony', 'liverpool', 'capao da canoa', 'aklavik', 'dickinson', 'bud', 'geraldton', 'necochea', 'gat', 'barajevo', 'kimbe', 'meyungs', 'fulitun', 'mbaiki', 'quatre cocos', 'yokadouma', 'izvoru crisului', 'prieska', 'ancud', 'haines junction', 'abha', 'chifeng', 'guiratinga', 'sola', 'srednekolymsk', 'bilma', 'vaitupu', 'inta', 'quelimane', 'labrea', 'kaitangata', 'nyrob', 'kavieng', 'cabo san lucas', 'meulaboh', 'xining', 'bokoro', 'palmer', 'bata', 'isangel', 'akyab ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Get weather data from Openweathermap and connect with api key to get access.

url = "https://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_key}&q="

# %%
#Use requests.get to get response from link and return to json.

weather_request = requests.get(query_url + city)
weather_json = weather_request.json()

weather_json
# Out:
# {'coord': {'lon': -35.4608, 'lat': -5.1989},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 301.65,
#   'feels_like': 305.3,
#   'temp_min': 301.65,
#   'temp_max': 301.65,
#   'pressure': 1009,
#   'humidity': 73,
#   'sea_level': 1009,
#   'grnd_level': 1008},
#  'visibility': 10000,
#  'wind': {'speed': 4.95, 'deg': 93, 'gust': 6.43},
#  'clouds': {'all': 39},
#  'dt': 1636056229,
#  'sys': {'type': 1,
#   'id': 8452,
#   'country': 'BR',
#   'sunrise': 1636012570,
#   'sunset': 1636056877},
#  'timezone': -10800,
#  'id': 3386213,
#  'name': 'Touros',
#  'cod': 200}

# %%
#Check that works by grabbing "name" out of the data to get city name.
city_return = weather_json["name"]
print(city_return)
# Out:
# Touros

# %%
#Create list to hold all the data columns.

country_name = []
cities_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
wind_speed = []
cloudiness = []
date = []
counter = 0

#Loop throgh the list of all cities and use "except" to skip errors.
print ("Begin!")
print ("----------------------------")

for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        cities_name.append(response["name"])
        country_name.append(response["sys"]["country"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        wind_speed.append(response["wind"]["speed"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["dt"])
        city_return = response["name"]
        counter = counter + 1
        
        
        print (f"Retieving Results for {counter}| {city_return}")
        
    except:
        print("City not found! Next...")
        pass
print ("----------------------------")
print("Processing Complete")
# Out:
# Begin!
# ----------------------------
# Retieving Results for 1| Pochinki
# Retieving Results for 2| Rikitea
# Retieving Results for 3| Udhampur
# Retieving Results for 4| Kruisfontein
# Retieving Results for 5| San Cristobal
# Retieving Results for 6| Thompson
# Retieving Results for 7| Portree
# Retieving Results for 8| Daloa
# Retieving Results for 9| Port Alfred
# Retieving Results for 10| Koslan
# Retieving Results for 11| Lavrentiya
# Retieving Results for 12| Gazli
# Retieving Results for 13| Albany
# Retieving Results for 14| Cayenne
# Retieving Results for 15| Dikson
# Retieving Results for 16| Nanchang
# Retieving Results for 17| Dhidhdhoo
# Retieving Results for 18| Comodoro Rivadavia
# Retieving Results for 19| Te Anau
# Retieving Results for 20| Saskylakh
# Retieving Results for 21| Kapaa
# Retieving Results for 22| Avarua
# Retieving Results for 23| Arraial do Cabo
# Retieving Results for 24| Polignano a Mare
# Retieving Results for 25| Khatanga
# Retieving Results for 26| Caravelas
# Retieving Results for 27| Half Moon Bay
# Retieving Results for 28| Cape Town
# Retieving Results for 29| Ribeira Grande
# Retieving Results for 30| Atuona
# Retieving Results for 31| Longyearbyen
# City not found! Next...
# Retieving Results for 32| Lucea
# Retieving Results for 33| Ahipara
# Retieving Results for 34| Punta Arenas
# City not found! Next...
# Retieving Results for 35| Kudahuvadhoo
# Retieving Results for 36| Filingué
# Retieving Results for 37| Qaanaaq
# Retieving Results for 38| Saint-Joseph
# Retieving Results for 39| Bluff
# Retieving Results for 40| Yellowknife
# Retieving Results for 41| Hualmay
# Retieving Results for 42| Pierre
# Retieving Results for 43| Chokurdakh
# City not found! Next...
# Retieving Results for 44| Hamilton
# Retieving Results for 45| San Patricio
# Retieving Results for 46| Flinders
# City not found! Next...
# Retieving Results for 47| Narsaq
# Retieving Results for 48| Busselton
# Retieving Results for 49| Tadine
# Retieving Results for 50| Lebu
# Retieving Results for 51| New Norfolk
# Retieving Results for 52| George Town
# Retieving Results for 53| Mattru
# Retieving Results for 54| Hilo
# Retieving Results for 55| Mahébourg
# Retieving Results for 56| Alihe
# Retieving Results for 57| Otjimbingwe
# Retieving Results for 58| Pangai
# Retieving Results for 59| Aswān
# Retieving Results for 60| Foam Lake
# Retieving Results for 61| Bredasdorp
# Retieving Results for 62| Hermanus
# Retieving Results for 63| Pacific Grove
# Retieving Results for 64| Port Hardy
# Retieving Results for 65| Tiznit Province
# Retieving Results for 66| Guerrero Negro
# Retieving Results for 67| Mikhaylovka
# Retieving Results for 68| Hambantota
# Retieving Results for 69| Redlands
# Retieving Results for 70| Monte Patria
# Retieving Results for 71| Mercedes
# Retieving Results for 72| Asău
# Retieving Results for 73| Touros
# Retieving Results for 74| Pangoa
# Retieving Results for 75| Sistranda
# Retieving Results for 76| Antalaha
# Retieving Results for 77| Tuatapere
# Retieving Results for 78| De Aar
# Retieving Results for 79| Ushuaia
# Retieving Results for 80| Butaritari
# Retieving Results for 81| Lüderitz
# Retieving Results for 82| Alofi
# City not found! Next...
# Retieving Results for 83| Arrondissement de Troyes
# Retieving Results for 84| Taoudenni
# Retieving Results for 85| Morros
# Retieving Results for 86| Samarai
# Retieving Results for 87| Souillac
# Retieving Results for 88| Barrow
# Retieving Results for 89| Toora-Khem
# Retieving Results for 90| Mataura
# Retieving Results for 91| Jutaí
# Retieving Results for 92| Whitehorse
# Retieving Results for 93| Hithadhoo
# Retieving Results for 94| Clyde River
# Retieving Results for 95| Shingū
# Retieving Results for 96| Morondava
# Retieving Results for 97| Emba
# Retieving Results for 98| Vanimo
# Retieving Results for 99| Nikolskoye
# Retieving Results for 100| Padang
# Retieving Results for 101| Ponta do Sol
# Retieving Results for 102| Upernavik
# Retieving Results for 103| Luanda
# Retieving Results for 104| Tiksi
# Retieving Results for 105| Phan Thiet
# Retieving Results for 106| Staraya Akkermanovka
# Retieving Results for 107| São Filipe
# Retieving Results for 108| Husavik
# Retieving Results for 109| Florø
# Retieving Results for 110| Hobart
# Retieving Results for 111| Qax
# Retieving Results for 112| Sinnamary
# Retieving Results for 113| Itarema
# Retieving Results for 114| Jamestown
# Retieving Results for 115| Lilongwe
# Retieving Results for 116| Vostok
# Retieving Results for 117| Mogok
# Retieving Results for 118| Pringsewu
# Retieving Results for 119| San Matías
# Retieving Results for 120| Abéché
# Retieving Results for 121| Klaksvík
# Retieving Results for 122| Katsuura
# City not found! Next...
# Retieving Results for 123| Hyères
# Retieving Results for 124| Takoradze
# Retieving Results for 125| Korla
# Retieving Results for 126| Raja
# Retieving Results for 127| Mar del Plata
# Retieving Results for 128| Puerto Ayora
# Retieving Results for 129| Najrān
# Retieving Results for 130| Vaini
# Retieving Results for 131| Buraidah
# Retieving Results for 132| Santa Isabel Rio Negro
# Retieving Results for 133| Coari
# Retieving Results for 134| Norman Wells
# Retieving Results for 135| Dunedin
# Retieving Results for 136| Grand-Santi
# Retieving Results for 137| Saint-Augustin
# Retieving Results for 138| Tasiilaq
# Retieving Results for 139| Faanui
# Retieving Results for 140| Plastun
# City not found! Next...
# Retieving Results for 141| Yumen
# Retieving Results for 142| Bairiki Village
# Retieving Results for 143| Barcelos
# Retieving Results for 144| Zhuhai
# Retieving Results for 145| Fuerte Olimpo
# Retieving Results for 146| Bethel
# Retieving Results for 147| Leningradskiy
# Retieving Results for 148| Pangnirtung
# Retieving Results for 149| Bima
# City not found! Next...
# Retieving Results for 150| Los Llanos de Aridane
# Retieving Results for 151| Innisfail
# Retieving Results for 152| Saldanha
# Retieving Results for 153| Nālūt
# Retieving Results for 154| Carnarvon
# Retieving Results for 155| Peniche
# Retieving Results for 156| Bambous Virieux
# Retieving Results for 157| Naze
# Retieving Results for 158| Lorengau
# Retieving Results for 159| Mugur-Aksy
# Retieving Results for 160| Tengzhou
# Retieving Results for 161| Yulara
# Retieving Results for 162| Araouane
# Retieving Results for 163| Cap Malheureux
# Retieving Results for 164| Jumla
# Retieving Results for 165| Hasaki
# Retieving Results for 166| Alice Springs
# Retieving Results for 167| Mehamn
# Retieving Results for 168| Jamame
# City not found! Next...
# Retieving Results for 169| Pevek
# Retieving Results for 170| Waipawa
# Retieving Results for 171| Maniitsoq
# Retieving Results for 172| Potosí
# Retieving Results for 173| Chirongui
# Retieving Results for 174| Lagoa
# Retieving Results for 175| Rodolfo Sánchez Taboada
# Retieving Results for 176| Namatanai
# Retieving Results for 177| Cururupu
# Retieving Results for 178| Port Elizabeth
# Retieving Results for 179| Katobu
# Retieving Results for 180| Tuapse
# Retieving Results for 181| Ouadda
# Retieving Results for 182| Ozernovskiy
# Retieving Results for 183| Buala
# Retieving Results for 184| Olafsvik
# Retieving Results for 185| Marsabit
# Retieving Results for 186| Esperance
# Retieving Results for 187| Codrington
# Retieving Results for 188| Port Hedland
# Retieving Results for 189| Killybegs
# Retieving Results for 190| Camaquã
# Retieving Results for 191| Antropovo
# Retieving Results for 192| Chaiyaphum
# Retieving Results for 193| Aquiraz
# Retieving Results for 194| Barra de São Francisco
# Retieving Results for 195| Iskateley
# Retieving Results for 196| Stokmarknes
# Retieving Results for 197| Nelson Bay
# Retieving Results for 198| Ketchikan
# Retieving Results for 199| Tazovsky
# Retieving Results for 200| Boa Vista
# Retieving Results for 201| Fuxin
# City not found! Next...
# Retieving Results for 202| Iranshahr
# Retieving Results for 203| Salekhard
# Retieving Results for 204| Umluj
# Retieving Results for 205| Natchitoches
# Retieving Results for 206| Cerrito
# Retieving Results for 207| Puerto Quijarro
# Retieving Results for 208| Shitanjing
# City not found! Next...
# City not found! Next...
# Retieving Results for 209| Teahupoo
# Retieving Results for 210| Boyolangu
# Retieving Results for 211| Castro
# Retieving Results for 212| Saint-Michel-des-Saints
# Retieving Results for 213| Uyuni
# City not found! Next...
# Retieving Results for 214| Bunbury
# Retieving Results for 215| Cidreira
# Retieving Results for 216| Cabugao
# Retieving Results for 217| Jām Sāhib
# Retieving Results for 218| Ulladulla
# Retieving Results for 219| Aldan
# Retieving Results for 220| Fortuna
# City not found! Next...
# Retieving Results for 221| Hopelchén
# Retieving Results for 222| Beringovskiy
# Retieving Results for 223| Saint Paul Harbor
# Retieving Results for 224| Erdenet
# Retieving Results for 225| Mora
# Retieving Results for 226| Whitefish
# Retieving Results for 227| Springfield
# Retieving Results for 228| Mâncio Lima
# Retieving Results for 229| Ucluelet
# Retieving Results for 230| Turukhansk
# Retieving Results for 231| Shenjiamen
# Retieving Results for 232| Broken Hill
# Retieving Results for 233| Kamenka
# Retieving Results for 234| Bay Roberts
# Retieving Results for 235| East London
# Retieving Results for 236| Bengkulu
# Retieving Results for 237| Saint-Philippe
# Retieving Results for 238| Sabzawār
# Retieving Results for 239| Mendoza
# Retieving Results for 240| Nizwá
# Retieving Results for 241| Saint George
# Retieving Results for 242| Tuktoyaktuk
# Retieving Results for 243| Kuusamo
# Retieving Results for 244| Batemans Bay
# Retieving Results for 245| Nizhniy Kuranakh
# City not found! Next...
# Retieving Results for 246| Vardø
# Retieving Results for 247| Makakilo City
# Retieving Results for 248| Prince Rupert
# Retieving Results for 249| Fukuechō
# Retieving Results for 250| Ambilobe
# Retieving Results for 251| Niceville
# Retieving Results for 252| Kieta
# City not found! Next...
# Retieving Results for 253| Coquimbo
# Retieving Results for 254| Bukachacha
# Retieving Results for 255| Amga
# City not found! Next...
# Retieving Results for 256| Wagar
# Retieving Results for 257| Huangnihe
# Retieving Results for 258| Orange
# Retieving Results for 259| Karratha
# Retieving Results for 260| Kailua
# Retieving Results for 261| Sawtell
# Retieving Results for 262| Nioro
# Retieving Results for 263| Saint Anthony
# Retieving Results for 264| Liverpool
# Retieving Results for 265| Capão da Canoa
# Retieving Results for 266| Aklavik
# Retieving Results for 267| Dickinson
# Retieving Results for 268| Bud
# Retieving Results for 269| Geraldton
# Retieving Results for 270| Necochea
# Retieving Results for 271| Kiryat Gat
# Retieving Results for 272| Barajevo
# Retieving Results for 273| Kimbe
# City not found! Next...
# City not found! Next...
# Retieving Results for 274| Mbaïki
# Retieving Results for 275| Quatre Cocos
# Retieving Results for 276| Yokadouma
# Retieving Results for 277| Izvoru Crişului
# Retieving Results for 278| Prieska
# Retieving Results for 279| Ancud
# Retieving Results for 280| Haines Junction
# Retieving Results for 281| Abhā
# Retieving Results for 282| Chifeng
# Retieving Results for 283| Guiratinga
# Retieving Results for 284| Sola
# Retieving Results for 285| Srednekolymsk
# Retieving Results for 286| Bilma
# City not found! Next...
# Retieving Results for 287| Inta
# Retieving Results for 288| Quelimane
# Retieving Results for 289| Lábrea
# Retieving Results for 290| Kaitangata
# Retieving Results for 291| Nyrob
# Retieving Results for 292| Kavieng
# Retieving Results for 293| Cabo San Lucas
# Retieving Results for 294| Meulaboh
# Retieving Results for 295| Xining
# Retieving Results for 296| Bokoro
# Retieving Results for 297| Palmer
# Retieving Results for 298| Bata
# Retieving Results for 299| Isangel
# Retieving Results for 300| Sittwe
# Retieving Results for 301| Luleå
# Retieving Results for 302| Moramanga
# Retieving Results for 303| Sitka
# Retieving Results for 304| Sārangarh
# Retieving Results for 305| Kloulklubed
# Retieving Results for 306| Muhos
# Retieving Results for 307| Pangody
# Retieving Results for 308| Usinsk
# Retieving Results for 309| Maryville
# Retieving Results for 310| Rabo de Peixe
# Retieving Results for 311| Iberia
# Retieving Results for 312| Ostrovnoy
# Retieving Results for 313| Mount Isa
# Retieving Results for 314| Mount Gambier
# Retieving Results for 315| Tambopata
# Retieving Results for 316| Valera
# Retieving Results for 317| Miraflores
# Retieving Results for 318| Baykit
# Retieving Results for 319| Lithakia
# Retieving Results for 320| Dhing
# Retieving Results for 321| Ngunguru
# Retieving Results for 322| Brae
# Retieving Results for 323| Yuanping
# Retieving Results for 324| Lafiagi
# City not found! Next...
# Retieving Results for 325| Saint-Pierre
# Retieving Results for 326| Danville
# Retieving Results for 327| Coyhaique
# Retieving Results for 328| Cherskiy
# Retieving Results for 329| Zárate
# Retieving Results for 330| Heinola
# Retieving Results for 331| Volchikha
# Retieving Results for 332| Collie
# Retieving Results for 333| Salym
# Retieving Results for 334| Frontera
# Retieving Results for 335| Bishoftu
# Retieving Results for 336| Leku
# City not found! Next...
# Retieving Results for 337| Punta Umbría
# Retieving Results for 338| Zhigansk
# Retieving Results for 339| Poum
# Retieving Results for 340| Córdoba
# Retieving Results for 341| Landázuri
# Retieving Results for 342| Marawi
# Retieving Results for 343| Rawson
# Retieving Results for 344| Omboué
# Retieving Results for 345| Drochia
# Retieving Results for 346| Pundaguitan
# Retieving Results for 347| Eureka
# Retieving Results for 348| Port Keats
# Retieving Results for 349| Mitla
# Retieving Results for 350| Cumberland
# Retieving Results for 351| Aykhal
# Retieving Results for 352| Resistencia
# Retieving Results for 353| Hamina
# Retieving Results for 354| Havelock
# Retieving Results for 355| Alamosa
# Retieving Results for 356| Tortolì
# Retieving Results for 357| Alberdi
# Retieving Results for 358| Lata
# Retieving Results for 359| Minuri
# Retieving Results for 360| Broome
# Retieving Results for 361| Vila Franca do Campo
# Retieving Results for 362| Pochutla
# Retieving Results for 363| Lompoc
# Retieving Results for 364| Hobyo
# City not found! Next...
# Retieving Results for 365| Chui
# Retieving Results for 366| Gisborne
# Retieving Results for 367| Kirakira
# Retieving Results for 368| Ixtapa
# Retieving Results for 369| Atemar
# Retieving Results for 370| Provideniya
# Retieving Results for 371| Labuhan
# Retieving Results for 372| Kropotkin
# Retieving Results for 373| Pisco
# Retieving Results for 374| Grand-Lahou
# City not found! Next...
# Retieving Results for 375| Maputo
# Retieving Results for 376| Nacala
# Retieving Results for 377| Yakeshi
# Retieving Results for 378| Sovetskiy
# Retieving Results for 379| Dudinka
# Retieving Results for 380| Upington
# City not found! Next...
# Retieving Results for 381| Hurghada
# Retieving Results for 382| Guánica
# City not found! Next...
# Retieving Results for 383| Khovd
# Retieving Results for 384| Ambulu
# Retieving Results for 385| Seymchan
# Retieving Results for 386| Nardaran
# Retieving Results for 387| Kumul
# Retieving Results for 388| Liaoyang
# City not found! Next...
# Retieving Results for 389| Slave Lake
# Retieving Results for 390| Hofn
# Retieving Results for 391| Airai
# Retieving Results for 392| Musoma
# City not found! Next...
# Retieving Results for 393| Chimoré
# City not found! Next...
# Retieving Results for 394| Doka
# Retieving Results for 395| Chernogolovka
# Retieving Results for 396| Matara
# City not found! Next...
# Retieving Results for 397| Constitución
# Retieving Results for 398| Acaraú
# Retieving Results for 399| Paamiut
# Retieving Results for 400| Merrill
# Retieving Results for 401| Nome
# Retieving Results for 402| Tateyama
# Retieving Results for 403| Port Moresby
# Retieving Results for 404| Yangmei
# Retieving Results for 405| Marystown
# Retieving Results for 406| Kyzyl
# Retieving Results for 407| Sur
# Retieving Results for 408| Pauini
# Retieving Results for 409| Ayamé
# Retieving Results for 410| Khani
# Retieving Results for 411| Port Blair
# Retieving Results for 412| Magalia
# Retieving Results for 413| Province of Mantua
# Retieving Results for 414| Marsá Maţrūḩ
# Retieving Results for 415| Mossamedes
# City not found! Next...
# Retieving Results for 416| Dakar
# Retieving Results for 417| Ponta Delgada
# Retieving Results for 418| Ramonville-Saint-Agne
# Retieving Results for 419| Keti Bandar
# Retieving Results for 420| Ruteng
# Retieving Results for 421| Morant Bay
# Retieving Results for 422| Porbandar
# Retieving Results for 423| Torbay
# Retieving Results for 424| Taitung City
# Retieving Results for 425| Mulegé
# Retieving Results for 426| Paso de los Toros
# Retieving Results for 427| Ust'-Ishim
# Retieving Results for 428| Morehead
# Retieving Results for 429| Bilibino
# Retieving Results for 430| Ormara
# Retieving Results for 431| Halifax
# Retieving Results for 432| Nishihara
# Retieving Results for 433| Kigoma
# Retieving Results for 434| Kenai
# City not found! Next...
# Retieving Results for 435| Port Lincoln
# Retieving Results for 436| Pimenta Bueno
# Retieving Results for 437| Berbera
# Retieving Results for 438| Waynesville
# Retieving Results for 439| Mtimbira
# Retieving Results for 440| Menongue
# Retieving Results for 441| Río Gallegos
# Retieving Results for 442| Havøysund
# Retieving Results for 443| Severo-Kuril'sk
# City not found! Next...
# Retieving Results for 444| Northam
# Retieving Results for 445| Iquique
# Retieving Results for 446| Äänekoski
# Retieving Results for 447| Coahuayana Viejo
# Retieving Results for 448| Ambon City
# Retieving Results for 449| Dhārchula
# Retieving Results for 450| Bathsheba
# Retieving Results for 451| San Antonio
# Retieving Results for 452| Nong’an
# Retieving Results for 453| Henties Bay
# Retieving Results for 454| Deep River
# Retieving Results for 455| Boca do Acre
# Retieving Results for 456| Kazachinskoye
# Retieving Results for 457| Sonoita
# Retieving Results for 458| Port-Gentil
# Retieving Results for 459| Province of Trapani
# City not found! Next...
# Retieving Results for 460| Kargopol'
# Retieving Results for 461| Coxim
# Retieving Results for 462| Caranavi
# Retieving Results for 463| Waingapu
# Retieving Results for 464| Āsbe Teferī
# Retieving Results for 465| College
# Retieving Results for 466| Santa Lucía
# City not found! Next...
# Retieving Results for 467| Harstad
# Retieving Results for 468| Honningsvåg
# Retieving Results for 469| Quesnel
# Retieving Results for 470| Paita
# Retieving Results for 471| Wawa
# Retieving Results for 472| Gorontalo
# City not found! Next...
# Retieving Results for 473| San Jerónimo
# Retieving Results for 474| Assiniboia
# Retieving Results for 475| Hwange
# Retieving Results for 476| Akdepe
# Retieving Results for 477| Provincie Utrecht
# Retieving Results for 478| Santa Elena
# Retieving Results for 479| Rome
# Retieving Results for 480| Juneau
# Retieving Results for 481| Zeya
# Retieving Results for 482| Abay
# Retieving Results for 483| Oskemen
# Retieving Results for 484| Klyuchi
# Retieving Results for 485| Hong Kong
# Retieving Results for 486| Beira
# Retieving Results for 487| Druzhba
# Retieving Results for 488| Inongo
# Retieving Results for 489| Zuénoula
# Retieving Results for 490| Revin
# Retieving Results for 491| Adrar
# Retieving Results for 492| Bull Savanna
# Retieving Results for 493| Mangai
# Retieving Results for 494| Westport
# Retieving Results for 495| Yar-Sale
# Retieving Results for 496| Tailai
# Retieving Results for 497| Viedma
# Retieving Results for 498| Chimbote
# Retieving Results for 499| Ipixuna
# City not found! Next...
# Retieving Results for 500| Lloydminster
# City not found! Next...
# City not found! Next...
# City not found! Next...
# Retieving Results for 501| Honiara
# Retieving Results for 502| Carutapera
# Retieving Results for 503| Miranda
# City not found! Next...
# Retieving Results for 504| Taylor
# Retieving Results for 505| Wasilla
# Retieving Results for 506| Bonavista
# Retieving Results for 507| Hilantagaan
# Retieving Results for 508| Raufoss
# City not found! Next...
# Retieving Results for 509| Palau
# Retieving Results for 510| Grindavik
# Retieving Results for 511| Rapid City
# Retieving Results for 512| Daru
# Retieving Results for 513| Alirajpur
# Retieving Results for 514| Fort Nelson
# Retieving Results for 515| Canguçu
# Retieving Results for 516| Colomi
# Retieving Results for 517| Ilulissat
# Retieving Results for 518| Aransas Pass
# Retieving Results for 519| Batamshinskiy
# City not found! Next...
# Retieving Results for 520| Krutinka
# Retieving Results for 521| Lubango
# Retieving Results for 522| Tayshet
# Retieving Results for 523| Vanderhoof
# Retieving Results for 524| Xai-Xai
# Retieving Results for 525| Yining
# Retieving Results for 526| Areosa
# City not found! Next...
# City not found! Next...
# Retieving Results for 527| Talnakh
# Retieving Results for 528| Damietta
# Retieving Results for 529| Merritt
# Retieving Results for 530| Borovoy
# Retieving Results for 531| Rondonópolis
# Retieving Results for 532| Sosnovo-Ozerskoye
# Retieving Results for 533| Parakou
# Retieving Results for 534| Acapulco de Juárez
# Retieving Results for 535| Managua
# Retieving Results for 536| Black River
# Retieving Results for 537| Sarangani
# Retieving Results for 538| Matamoros
# Retieving Results for 539| Vila
# Retieving Results for 540| Karwar
# Retieving Results for 541| Paso de Carrasco
# Retieving Results for 542| Ruidoso
# Retieving Results for 543| Iqaluit
# Retieving Results for 544| Jalu
# Retieving Results for 545| Laguna
# City not found! Next...
# Retieving Results for 546| Zholymbet
# Retieving Results for 547| Saldus
# Retieving Results for 548| ‘Āhuimanu
# Retieving Results for 549| Bonfim
# City not found! Next...
# Retieving Results for 550| Homer
# Retieving Results for 551| Lufilufi
# Retieving Results for 552| Antalya Province
# Retieving Results for 553| Wanning
# Retieving Results for 554| Leshukonskoye
# Retieving Results for 555| Laas
# Retieving Results for 556| Deputatsky
# Retieving Results for 557| Kjøllefjord
# ----------------------------
# Processing Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Storing data and create DataFrame to display.

weather_store = {"Country": country_name, "City": cities_name, "Latitude": latitude, "Longitude": longitude,
                "Max Temperature": max_temp, "Humidity": humidity, "Wind Speed": wind_speed, "Cloudiness": cloudiness, 
                "Date":date}
weather_data = pd.DataFrame(weather_store)
weather_data.head()
# Out:
#   Country           City  Latitude  Longitude  Max Temperature  Humidity  \
# 0      RU       Pochinki   54.6988    44.8668           277.80        61
# 1      PF        Rikitea  -23.1203  -134.9692           296.05        80
# 2      IN       Udhampur   32.9333    75.1333           287.06        51
# 3      ZA   Kruisfontein  -34.0033    24.7314           287.53        87
# 4      VE  San Cristobal    7.7669   -72.2250           300.25        59
#
#    Wind Speed  Cloudiness        Date
# 0        5.62         100  1636056232
# 1        4.50         100  1636056233
# 2        3.53          24  1636056233
# 3        0.09          58  1636056234
# 4        0.77          99  1636056234

# %%
pd.DataFrame(weather_data.describe())
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Wind Speed  \
# count  557.000000  557.000000       557.000000  557.000000  557.000000
# mean    19.327944   12.889639       287.939767   71.874327    3.470790
# std     33.938821   91.776311        12.969095   20.578731    2.633058
# min    -54.800000 -175.200000       247.790000    7.000000    0.000000
# 25%     -9.085300  -66.976400       280.380000   60.000000    1.520000
# 50%     22.678300   19.234500       290.400000   77.000000    2.890000
# 75%     48.649900   92.466700       298.130000   87.000000    4.730000
# max     78.218600  179.316700       312.320000  100.000000   17.430000
#
#        Cloudiness          Date
# count  557.000000  5.570000e+02
# mean    60.434470  1.636056e+09
# std     38.940437  1.128665e+02
# min      0.000000  1.636056e+09
# 25%     18.000000  1.636056e+09
# 50%     75.000000  1.636056e+09
# 75%     99.000000  1.636056e+09
# max    100.000000  1.636057e+09

# %%
#Save data to CSV
weather_data.to_csv("../weather_data.csv")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Max Temperature Plot

# %%
#Generate Scatter Plot for Latitude vs. Max Temperature.

plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], facecolors ="lightskyblue",
            marker = "o", edgecolor = "black")

plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Latitude vs. Max Temperature (11/04/2020)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()
plt.show()

plt.savefig("../data_images/Lat_vs_MaxTemp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Generate Scatter Plot for Latitude vs. Humidity.

plt.scatter(weather_data["Latitude"], weather_data["Humidity"], facecolors ="orange",
            marker = "o", edgecolor = "red")

plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs. Humidity (11/04/2020)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()
plt.show()

plt.savefig("../data_images/Lat_vs_Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Generate Scatter Plot for Latitude vs. Cloudiness.

plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], facecolors ="pink",
            marker = "o", edgecolor = "grey")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs. Cloudiness (11/04/2020)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()
plt.show()

plt.savefig("../data_images/Lat_vs_Cloudiness")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Generate Scatter Plot vs. Wind Speed.

plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], facecolors ="lime",
            marker = "o", edgecolor = "orange")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs. Wind Speed (11/04/2020)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()
plt.show()

plt.savefig("../data_images/Lat_vs_WindSpeed.png")

# %% [markdown]
# ## Linear Regression

# %%
#Separating them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and 
#Southern Hemisphere (less than 0 degrees latitude):

southern = weather_data.drop(weather_data[weather_data["Latitude"]<0].index)
southern
# Out:
#     Country            City  Latitude  Longitude  Max Temperature  Humidity  \
# 1        GF        Iracoubo    5.4802   -53.2011           302.83        63
# 3        CA     Fort Nelson   58.8053  -122.7002           273.81        81
# 5        MX  Cabo San Lucas   22.8909  -109.9124           303.18        45
# 7        RU   Leningradskiy   69.3833   178.4167           250.21        93
# 8        RU        Parabel'   58.6978    81.4825           264.91        86
# ..      ...             ...       ...        ...              ...       ...
# 583      VE      San Felipe   10.3399   -68.7425           301.62        72
# 584      NE           Arlit   18.7369     7.3853           304.72        13
# 585      VE       Maracaibo   10.6317   -71.6406           304.63        58
# 586      BS   Marsh Harbour   26.5412   -77.0636           298.88        60
# 587      LK      Hambantota    6.1241    81.1185           299.59        82
#
#      Wind Speed  Cloudiness        Date
# 1          4.28          47  1636045729
# 3          1.02          97  1636045481
# 5          0.00           1  1636045502
# 7          2.69          50  1636045731
# 8          5.24         100  1636045732
# ..          ...         ...         ...
# 583        2.83          72  1636046191
# 584        0.54           0  1636046125
# 585        2.09          95  1636046192
# 586        2.54          95  1636046193
# 587        5.59          72  1636046193
#
# [390 rows x 9 columns]

# %%
southern.describe()
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Wind Speed  \
# count  390.000000  390.000000       390.000000  390.000000  390.000000
# mean    39.224040   14.825279       284.659718   72.789744    3.523897
# std     20.107456   87.803429        13.961434   19.696982    2.561743
# min      0.516700 -179.166700       247.430000    9.000000    0.000000
# 25%     22.085775  -67.659275       276.470000   62.000000    1.472500
# 50%     41.415850   22.610350       284.215000   76.000000    2.995000
# 75%     55.682775   85.446050       297.517500   88.000000    4.910000
# max     78.218600  179.316700       310.720000  100.000000   12.370000
#
#        Cloudiness          Date
# count  390.000000  3.900000e+02
# mean    62.576923  1.636046e+09
# std     37.645389  1.703812e+02
# min      0.000000  1.636045e+09
# 25%     23.000000  1.636046e+09
# 50%     75.000000  1.636046e+09
# 75%     99.000000  1.636046e+09
# max    100.000000  1.636046e+09

# %%
northern = weather_data.drop(weather_data[weather_data["Latitude"]>=0].index)
northern
# Out:
#     Country             City  Latitude  Longitude  Max Temperature  Humidity  \
# 0        AU  Charters Towers  -20.1000   146.2667           292.92        86
# 2        AU        Esperance  -33.8667   121.9000           290.06        94
# 4        BR         Cidreira  -30.1811   -50.2056           295.74        83
# 6        AU      New Norfolk  -42.7826   147.0587           281.90        75
# 10       BR      Santa Maria  -29.6842   -53.8069           301.96        52
# ..      ...              ...       ...        ...              ...       ...
# 571      AR         La Rioja  -29.4111   -66.8507           295.16        56
# 575      MU     Quatre Cocos  -20.2078    57.7625           295.98        71
# 576      BR       Rio Grande  -32.0350   -52.0986           300.21        72
# 578      PF          Tautira  -17.7333  -149.1500           298.16        76
# 588      TZ         Mtambile   -5.3833    39.7000           299.12        82
#
#      Wind Speed  Cloudiness        Date
# 0          3.41           0  1636045724
# 2          4.02          19  1636045729
# 4          4.45          32  1636045574
# 6          0.93           0  1636045506
# 10         2.82           0  1636045733
# ..          ...         ...         ...
# 571        9.91          51  1636046186
# 575        4.36           0  1636046096
# 576        0.68          35  1636046021
# 578        6.55          70  1636046189
# 588        3.81          20  1636045718
#
# [199 rows x 9 columns]

# %%
northern.describe()
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Wind Speed  \
# count  199.000000  199.000000       199.000000  199.000000  199.000000
# mean   -20.271390   24.542129       296.011206   68.140704    3.666181
# std     13.440275   92.850051         6.625608   20.643690    2.413862
# min    -54.800000 -175.200000       278.480000    9.000000    0.000000
# 25%    -31.743750  -56.034850       292.080000   55.500000    1.820000
# 50%    -20.100000   22.747400       297.060000   73.000000    3.320000
# 75%     -8.153200  118.555200       300.200000   82.000000    4.840000
# max     -0.481900  174.500000       311.890000  100.000000   15.430000
#
#        Cloudiness          Date
# count  199.000000  1.990000e+02
# mean    58.688442  1.636046e+09
# std     36.058362  1.705559e+02
# min      0.000000  1.636046e+09
# 25%     25.000000  1.636046e+09
# 50%     71.000000  1.636046e+09
# 75%     94.000000  1.636046e+09
# max    100.000000  1.636046e+09

# %% [markdown]
# ## Max Temperature and Latitude
# * In Southern Hemisphere has a strong negative relationship as r-value = -0.85
# * In Northern Hemisphere has a strong positive relationship as r-value = 0.72

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern["Latitude"], southern["Max Temperature"])

#plot the data 
plt.scatter(southern["Latitude"], southern["Max Temperature"], marker="o", facecolors ="purple", edgecolor = "slategrey")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Southern Hemisphere - Max Temperature vs. Latitude (11/04/2021)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()

#Save figure
plt.savefig("../data_images/Southern_MaxTemp_Lat.png")

#Show figure
plt.show()

#Detemine R value
print(f"The r-square is {rvalue}.")
# Out:
# The r-square is -0.8543422436329998.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern["Latitude"], northern["Max Temperature"])

#plot the data 
plt.scatter(northern["Latitude"], northern["Max Temperature"], marker="o",facecolors ="grey", edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Northern Hemisphere - Max Temperature vs. Latitude (11/04/2021)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()

#Save figure
plt.savefig("../data_images/Northern_MaxTemp_Lat.png")

#Show figure
plt.show()

#Detemine R value
print(f"The r-square is {rvalue}.")
# Out:
# The r-square is 0.6660546846756169.

# %% [markdown]
# ## Humidity and Latitude
# * In Southern Hemisphere has a small positive relationship as r-value = 0.29
# * In Northern Hemisphere has no relationship as r-value = 0.05

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern["Latitude"], southern["Humidity"])

#plot the data 
plt.scatter(southern["Latitude"], southern["Humidity"], marker="o", facecolors ="darksalmon", edgecolor = "darkmagenta")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere - Humidity vs. Latitude (11/04/2021)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()

#Save figure
plt.savefig("../data_images/Southern_Humidity_Lat.png")

#Show figure
plt.show()

#Detemine R value
print(f"The r-square is {rvalue}.")
# Out:
# The r-square is 0.2953672532362608.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern["Latitude"], northern["Humidity"])

#plot the data 
plt.scatter(northern["Latitude"], northern["Humidity"], marker="o",facecolors ="wheat", edgecolor = "tomato")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere - Humidity vs. Latitude (11/04/2021)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()

#Save figure
plt.savefig("../data_images/Northern_Humidity_Lat.png")

#Show figure
plt.show()

#Detemine R value
print(f"The r-square is {rvalue}.")
# Out:
# The r-square is 0.06266763365922445.

# %% [markdown]
# ## Cloudiness and Latitude
# * In Southern Hemisphere has a small positive relationship as r-value = 0.18
# * In Northern Hemisphere has a small positive relationship as r-value = 0.24

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern["Latitude"], southern["Cloudiness"])

#plot the data 
plt.scatter(southern["Latitude"], southern["Cloudiness"], marker="o", facecolors ="paleturquoise", edgecolor = "slateblue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere - Cloudiness vs. Latitude (11/04/2021)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()

#Save figure
plt.savefig("../data_images/Southern_Cloudiness_Lat.png")

#Show figure
plt.show()

#Detemine R value
print(f"The r-square is {rvalue}.")
# Out:
# The r-square is 0.17728420869917624.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern["Latitude"], northern["Cloudiness"])

#plot the data 
plt.scatter(northern["Latitude"], northern["Cloudiness"], marker="o",facecolors ="deepskyblue", edgecolor = "plum")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere - Cloudiness vs. Latitude (11/04/2021)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()

#Save figure
plt.savefig("../data_images/Northern_Cloudiness_Lat.png")

#Show figure
plt.show()

#Detemine R value
print(f"The r-square is {rvalue}.")
# Out:
# The r-square is 0.1834683204044638.

# %% [markdown]
# ## Wind Speed and Latitude
# * In Southern Hemisphere has a small positive relationship as r-value = 0.18
# * In Northern Hemisphere has a small negative relationship as r-value = -0.19

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern["Latitude"], southern["Wind Speed"])

#plot the data 
plt.scatter(southern["Latitude"], southern["Wind Speed"], marker="o", facecolors ="peru", edgecolor = "crimson")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Southern Hemisphere - Wind Speed vs. Latitude (11/04/2021)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()

#Save figure
plt.savefig("../data_images/Southern_WindSpeed_Lat.png")

#Show figure
plt.show()

#Detemine R value
print(f"The r-square is {rvalue}.")
# Out:
# The r-square is 0.21454366460641378.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern["Latitude"], northern["Wind Speed"])

#plot the data 
plt.scatter(northern["Latitude"], northern["Wind Speed"], marker="o",facecolors ="darkorange", edgecolor = "indigo")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Northern Hemisphere - Wind Speed vs. Latitude (11/04/2021)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()

#Save figure
plt.savefig("../data_images/Northern_WindSpeed_Lat.png")

#Show figure
plt.show()

#Detemine R value
print(f"The r-square is {rvalue}.")
# Out:
# The r-square is -0.20732266092938892.
