# %%
#Dependencies

import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import scipy.stats as st
import json
import time

from weather_api import api_key

from citipy import citipy

# %%
#Import data
data = "../output_data/cities.csv"
cities = pd.read_csv(data)
cities = cities.set_index("City")

cities
# Out:
#              City_ID  Cloudiness Country        Date  Humidity    Lat     Lng  \
# City
# ostrovnoy          0           2      RU  1558378754        72  68.05   39.51
# mahebourg          1          75      MU  1558378503        74 -20.41   57.70
# qaanaaq            2          25      GL  1558378755        73  77.48  -69.36
# zhuhai             3           0      CN  1558378755        39  40.71  112.04
# cape town          4          20      ZA  1558378755        76 -33.93   18.42
# ...              ...         ...     ...         ...       ...    ...     ...
# yabrud           543           0      SY  1558378840        32  33.97   36.66
# paraiso          544           5      MX  1558378898         4  24.01 -104.61
# veraval          545           0      FR  1558378898        62  49.65    0.71
# novyy urgal      546         100      RU  1558378899        93  51.07  132.56
# tongren          547           4      CN  1558378899        64  27.72  109.18
#
#              Max Temp  Wind Speed
# City
# ostrovnoy       37.50        7.16
# mahebourg       78.80       11.41
# qaanaaq         22.20        2.37
# zhuhai          44.60        4.47
# cape town       55.99        8.05
# ...               ...         ...
# yabrud          80.60        8.05
# paraiso         84.20       16.11
# veraval         61.00        8.05
# novyy urgal     49.74        2.68
# tongren         55.86        2.84
#
# [548 rows x 9 columns]

# %%
#Range Latitud/Longitude and create list to hold both of it. 

latitude = (-90, 90)
longitude =(-180, 180)
lat_lng = []

#Create list to hold cities.
cities = []

#Crete set of Latitude and Longitude with random.
lat = np.random.uniform(latitude[0], latitude[1], size = 1500)
lng = np.random.uniform(longitude[0], longitude[1], size=1500)

lat_lng = zip(lat, lng)

#Generate cities list.
for lat_lngs in lat_lng:
    city = citipy.nearest_city(lat_lngs[0], lat_lngs[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 637

# %%
#Check cities list.
print(cities)
# Out:
# ['mago', 'amderma', 'hilo', 'faanui', 'atuona', 'le port', 'hermanus', 'bagepalli', 'ribeira grande', 'arraial do cabo', 'chuy', 'barrow', 'tsihombe', 'nobres', 'rikitea', 'busselton', 'hofn', 'bluff', 'khatanga', 'beyneu', 'yar-sale', 'mataura', 'gamba', 'saint-philippe', 'saldanha', 'khokhryaki', 'tweed', 'vanimo', 'shimanovsk', 'byron bay', 'marcona', 'narsaq', 'vetovo', 'petropavlovsk-kamchatskiy', 'codrington', 'ilulissat', 'punta arenas', 'bathsheba', 'rockingham', 'praia da vitoria', 'port alfred', 'gannan', 'ardakan', 'altay', 'cidreira', 'tasiilaq', 'yeroham', 'pevek', 'teacapan', 'miyako', 'pimentel', 'miranorte', 'ruteng', 'port elizabeth', 'kiama', 'hobart', 'umm lajj', 'dingle', 'bageshwar', 'mozarlandia', 'san cristobal', 'saleaula', 'beringovskiy', 'vaini', 'nizhneyansk', 'hithadhoo', 'yarim', 'bridlington', 'cilegon', 'banjar', 'nioro', 'nyurba', 'bethel', 'porto novo', 'vedaranniyam', 'palmer', 'ushuaia', 'longyearbyen', 'vallenar', 'dikson', 'hay river', 'katsina', 'lompoc', 'cap malheureux', 'bredasdorp', 'cape town', 'yulara', 'sarankhola', 'anadyr', 'kamennogorsk', 'soyo', 'crab hill', 'primorsk', 'torbay', 'illoqqortoormiut', 'broken hill', 'coquimbo', 'karamken', 'toliary', 'margate', 'taoudenni', 'canto do buriti', 'ketchikan', 'albany', 'butaritari', 'yellowknife', 'poya', 'carnarvon', 'puerto ayora', 'mvuma', 'whitstable', 'misantla', 'katsuura', 'lambarene', 'morgantown', 'kuri', 'kodiak', 'manbij', 'severo-kurilsk', 'genhe', 'vao', 'upernavik', 'bonnyville', 'touros', 'nikolskoye', 'mao', 'kupang', 'heyang', 'lagoa', 'tuktoyaktuk', 'porto velho', 'jamestown', 'cherskiy', 'guerrero negro', 'manakara', 'ovalle', 'saskylakh', 'ouesso', 'zamora', 'bulgan', 'luderitz', 'kodinsk', 'vendome', 'homer', 'aklavik', 'harper', 'isilkul', 'nicolas bravo', 'ko samui', 'haibowan', 'curillo', 'itzincab', 'saint-pierre', 'bukama', 'abu dhabi', 'grand river south east', 'belushya guba', 'anamur', 'tuatapere', 'tukrah', 'buchanan', 'aykhal', 'taolanaro', 'mar del plata', 'metro', 'kieta', 'cazones', 'kargasok', 'pisco', 'bambous virieux', 'avarua', 'east london', 'mahebourg', 'hami', 'uruzgan', 'bonavista', 'warqla', 'qaanaaq', 'new norfolk', 'westport', 'san rafael', 'kazachinskoye', 'ranong', 'novikovo', 'georgetown', 'kapaa', 'hearst', 'ponta delgada', 'alofi', 'priladozhskiy', 'bria', 'thompson', 'kolga', 'kathu', 'oistins', 'xichang', 'khormuj', 'ponta do sol', 'vaitupu', 'norman wells', 'tiksi', 'airai', 'vila franca do campo', 'evensk', 'lazurne', 'bur gabo', 'aasiaat', 'escarcega', 'dunedin', 'visnes', 'victoria', 'nishihara', 'samusu', 'sorvag', 'sakaraha', 'verkhnyaya inta', 'aitape', 'shizunai', 'port-de-paix', 'vasteras', 'sentyabrskiy', 'ancud', 'lethem', 'chernyshevskiy', 'preeceville', 'zolotinka', 'lata', 'laramie', 'nanortalik', 'vaovai', 'bull savanna', 'barentsburg', 'goderich', 'adrar', 'shingu', 'otradinskiy', 'port blair', 'raudeberg', 'nuuk', 'deputatskiy', 'faya', 'laurel', 'bodden town', 'serabu', 'santiago', 'kalmunai', 'prieska', 'samarai', 'bengkulu', 'whyalla', 'padang', 'havoysund', 'erzin', 'kenai', 'klaksvik', 'grand gaube', 'ust-ilimsk', 'honiara', 'nago', 'college', 'mardin', 'salme', 'christchurch', 'dali', 'ararangua', 'freeport', 'westerland', 'tomatlan', 'little rock', 'nanyang', 'kadykchan', 'esperance', 'witu', 'tarko-sale', 'hervey bay', 'adolfo lopez mateos', 'caravelas', 'doha', 'kavieng', 'cumberland', 'bani walid', 'saint george', 'maragogi', 'kutum', 'kruisfontein', 'bealanana', 'waipawa', 'zhanakorgan', 'moyale', 'nouadhibou', 'adigeni', 'clyde river', 'konstantinovka', 'port hueneme', 'cabo san lucas', 'maraba', 'castro', 'atbasar', 'kushmurun', 'lebu', 'camacha', 'fomboni', 'kamenskoye', 'tual', 'hanko', 'soller', 'yeppoon', 'alugan', 'ust-bolsheretsk', 'orlik', 'bangolo', 'karaman', 'zambezi', 'san patricio', 'olafsvik', 'los llanos de aridane', 'barbar', 'xai-xai', 'fortuna', 'tazovskiy', 'krasnyy yar', 'port hedland', 'shetpe', 'agutaya', 'boyuibe', 'huarmey', 'yanta ...

# %%
#Get weather data from Openweathermap and connect with api key to get access.

url = "https://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_key}&q="

# %%
#Use requests.get to get response from link and return to json.

weather_request = requests.get(query_url + city)
weather_json = weather_request.json()

weather_json
# Out:
# {'coord': {'lon': -28.7, 'lat': 38.5167},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 296.42,
#   'feels_like': 297.02,
#   'temp_min': 296.42,
#   'temp_max': 296.42,
#   'pressure': 1013,
#   'humidity': 85,
#   'sea_level': 1013,
#   'grnd_level': 1013},
#  'visibility': 10000,
#  'wind': {'speed': 4.82, 'deg': 264, 'gust': 6.07},
#  'clouds': {'all': 79},
#  'dt': 1630466268,
#  'sys': {'country': 'PT', 'sunrise': 1630481063, 'sunset': 1630527934},
#  'timezone': 0,
#  'id': 3372707,
#  'name': 'Ribeira Grande',
#  'cod': 200}

# %%
#Check that works by grabbing "name" out of the data to get city name.
city_return = weather_json["name"]
print(city_return)
# Out:
# Ribeira Grande

# %%
#Create list to hold all the data columns.

country_name = []
cities_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
wind_speed = []
cloudiness = []
date = []
counter = 0

#Loop throgh the list of all cities and use "except" to skip errors.
print ("Begin!")
print ("----------------------------")

for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        cities_name.append(response["name"])
        country_name.append(response["sys"]["country"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        wind_speed.append(response["wind"]["speed"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["dt"])
        city_return = response["name"]
        counter = counter + 1
        
        
        print (f"Retieving Results for {counter}| {city_return}")
        
    except:
        print("City not found! Next...")
        pass
print ("----------------------------")
print("Processing Complete")
# Out:
# Begin!
# ----------------------------
# Retieving Results for 1| Mago
# City not found! Next...
# Retieving Results for 2| Hilo
# Retieving Results for 3| Faanui
# Retieving Results for 4| Atuona
# Retieving Results for 5| Le Port
# Retieving Results for 6| Hermanus
# Retieving Results for 7| Bāgepalli
# Retieving Results for 8| Ribeira Grande
# Retieving Results for 9| Arraial do Cabo
# Retieving Results for 10| Chui
# Retieving Results for 11| Barrow
# City not found! Next...
# Retieving Results for 12| Nobres
# Retieving Results for 13| Rikitea
# Retieving Results for 14| Busselton
# Retieving Results for 15| Hofn
# Retieving Results for 16| Bluff
# Retieving Results for 17| Khatanga
# Retieving Results for 18| Beyneu
# Retieving Results for 19| Yar-Sale
# Retieving Results for 20| Mataura
# Retieving Results for 21| Gamba
# Retieving Results for 22| Saint-Philippe
# Retieving Results for 23| Saldanha
# Retieving Results for 24| Khokhryaki
# Retieving Results for 25| Tweed
# Retieving Results for 26| Vanimo
# Retieving Results for 27| Shimanovsk
# Retieving Results for 28| Byron Bay
# City not found! Next...
# Retieving Results for 29| Narsaq
# Retieving Results for 30| Vetovo
# Retieving Results for 31| Petropavlovsk-Kamchatskiy
# Retieving Results for 32| Codrington
# Retieving Results for 33| Ilulissat
# Retieving Results for 34| Punta Arenas
# Retieving Results for 35| Bathsheba
# Retieving Results for 36| Rockingham
# Retieving Results for 37| Praia da Vitória
# Retieving Results for 38| Port Alfred
# Retieving Results for 39| Gannan
# Retieving Results for 40| Ardakān
# Retieving Results for 41| Altay
# Retieving Results for 42| Cidreira
# Retieving Results for 43| Tasiilaq
# Retieving Results for 44| Yeruham
# Retieving Results for 45| Pevek
# Retieving Results for 46| Teacapan
# Retieving Results for 47| Miyako
# Retieving Results for 48| Pimentel
# City not found! Next...
# Retieving Results for 49| Ruteng
# Retieving Results for 50| Port Elizabeth
# Retieving Results for 51| Kiama
# Retieving Results for 52| Hobart
# Retieving Results for 53| Umluj
# Retieving Results for 54| Dingle
# Retieving Results for 55| Bāgeshwar
# Retieving Results for 56| Mozarlândia
# Retieving Results for 57| San Cristobal
# City not found! Next...
# Retieving Results for 58| Beringovskiy
# Retieving Results for 59| Vaini
# City not found! Next...
# Retieving Results for 60| Hithadhoo
# Retieving Results for 61| Yarim
# Retieving Results for 62| Bridlington
# Retieving Results for 63| Cilegon
# Retieving Results for 64| Banjar
# Retieving Results for 65| Nioro
# Retieving Results for 66| Nyurba
# Retieving Results for 67| Bethel
# Retieving Results for 68| Porto-Novo
# City not found! Next...
# Retieving Results for 69| Palmer
# Retieving Results for 70| Ushuaia
# Retieving Results for 71| Longyearbyen
# Retieving Results for 72| Vallenar
# Retieving Results for 73| Dikson
# Retieving Results for 74| Hay River
# Retieving Results for 75| Katsina
# Retieving Results for 76| Lompoc
# Retieving Results for 77| Cap Malheureux
# Retieving Results for 78| Bredasdorp
# Retieving Results for 79| Cape Town
# Retieving Results for 80| Yulara
# Retieving Results for 81| Sarankhola
# Retieving Results for 82| Anadyr
# Retieving Results for 83| Kamennogorsk
# Retieving Results for 84| Soyo
# City not found! Next...
# Retieving Results for 85| Prymors'k
# Retieving Results for 86| Torbay
# City not found! Next...
# Retieving Results for 87| Broken Hill
# Retieving Results for 88| Coquimbo
# City not found! Next...
# City not found! Next...
# Retieving Results for 89| Margate
# Retieving Results for 90| Taoudenni
# Retieving Results for 91| Canto do Buriti
# Retieving Results for 92| Ketchikan
# Retieving Results for 93| Albany
# Retieving Results for 94| Butaritari
# Retieving Results for 95| Yellowknife
# Retieving Results for 96| Poya
# Retieving Results for 97| Carnarvon
# Retieving Results for 98| Puerto Ayora
# Retieving Results for 99| Mvuma
# Retieving Results for 100| Whitstable
# Retieving Results for 101| Misantla
# Retieving Results for 102| Katsuura
# Retieving Results for 103| Lambaréné
# Retieving Results for 104| Morgantown
# Retieving Results for 105| Guri-si
# Retieving Results for 106| Saint Paul Harbor
# Retieving Results for 107| Manbij
# Retieving Results for 108| Severo-Kuril'sk
# Retieving Results for 109| Genhe
# Retieving Results for 110| Vao
# Retieving Results for 111| Upernavik
# Retieving Results for 112| Bonnyville
# Retieving Results for 113| Touros
# Retieving Results for 114| Nikolskoye
# Retieving Results for 115| Mahon
# Retieving Results for 116| Kupang
# Retieving Results for 117| Heyang
# Retieving Results for 118| Lagoa
# Retieving Results for 119| Tuktoyaktuk
# Retieving Results for 120| Porto Velho
# Retieving Results for 121| Jamestown
# Retieving Results for 122| Cherskiy
# Retieving Results for 123| Guerrero Negro
# Retieving Results for 124| Manakara
# Retieving Results for 125| Ovalle
# Retieving Results for 126| Saskylakh
# Retieving Results for 127| Ouésso
# Retieving Results for 128| Zamora
# Retieving Results for 129| Bulgan
# Retieving Results for 130| Lüderitz
# Retieving Results for 131| Kodinsk
# Retieving Results for 132| Vendôme
# Retieving Results for 133| Homer
# Retieving Results for 134| Aklavik
# Retieving Results for 135| Harper
# Retieving Results for 136| Isil'kul'
# Retieving Results for 137| Nicolás Bravo
# Retieving Results for 138| Ko Samui
# City not found! Next...
# Retieving Results for 139| Curillo
# City not found! Next...
# Retieving Results for 140| Saint-Pierre
# Retieving Results for 141| Bukama
# Retieving Results for 142| Abu Dhabi
# City not found! Next...
# City not found! Next...
# Retieving Results for 143| Anamur
# Retieving Results for 144| Tuatapere
# Retieving Results for 145| Tūkrah
# Retieving Results for 146| Buchanan
# Retieving Results for 147| Aykhal
# City not found! Next...
# Retieving Results for 148| Mar del Plata
# Retieving Results for 149| Metro
# Retieving Results for 150| Kieta
# Retieving Results for 151| Cazones de Herrera
# Retieving Results for 152| Kargasok
# Retieving Results for 153| Pisco
# Retieving Results for 154| Bambous Virieux
# Retieving Results for 155| Avarua
# Retieving Results for 156| East London
# Retieving Results for 157| Mahébourg
# Retieving Results for 158| Kumul
# Retieving Results for 159| Oruzgan
# Retieving Results for 160| Bonavista
# City not found! Next...
# Retieving Results for 161| Qaanaaq
# Retieving Results for 162| New Norfolk
# Retieving Results for 163| Westport
# Retieving Results for 164| San Rafael
# Retieving Results for 165| Kazachinskoye
# Retieving Results for 166| Ranong
# Retieving Results for 167| Novikovo
# Retieving Results for 168| George Town
# Retieving Results for 169| Kapaa
# Retieving Results for 170| Hearst
# Retieving Results for 171| Ponta Delgada
# Retieving Results for 172| Alofi
# Retieving Results for 173| Priladozhskiy
# Retieving Results for 174| Bria
# Retieving Results for 175| Thompson
# Retieving Results for 176| Kolga
# Retieving Results for 177| Kathu
# Retieving Results for 178| Oistins
# Retieving Results for 179| Xichang
# City not found! Next...
# Retieving Results for 180| Ponta do Sol
# City not found! Next...
# Retieving Results for 181| Norman Wells
# Retieving Results for 182| Tiksi
# Retieving Results for 183| Airai
# Retieving Results for 184| Vila Franca do Campo
# Retieving Results for 185| Evensk
# Retieving Results for 186| Lazurne
# City not found! Next...
# Retieving Results for 187| Aasiaat
# Retieving Results for 188| Escárcega
# Retieving Results for 189| Dunedin
# Retieving Results for 190| Visnes
# Retieving Results for 191| Hong Kong
# Retieving Results for 192| Nishihara
# City not found! Next...
# City not found! Next...
# Retieving Results for 193| Sakaraha
# Retieving Results for 194| Verkhnyaya Inta
# Retieving Results for 195| Aitape
# Retieving Results for 196| Shizunai-furukawachō
# City not found! Next...
# Retieving Results for 197| Västerås
# City not found! Next...
# Retieving Results for 198| Ancud
# Retieving Results for 199| Lethem
# Retieving Results for 200| Chernyshevskiy
# Retieving Results for 201| Preeceville
# City not found! Next...
# Retieving Results for 202| Lata
# Retieving Results for 203| Laramie
# Retieving Results for 204| Nanortalik
# City not found! Next...
# Retieving Results for 205| Bull Savanna
# City not found! Next...
# Retieving Results for 206| Goderich
# Retieving Results for 207| Adrar
# Retieving Results for 208| Shingū
# City not found! Next...
# Retieving Results for 209| Port Blair
# Retieving Results for 210| Raudeberg
# Retieving Results for 211| Nuuk
# Retieving Results for 212| Deputatsky
# Retieving Results for 213| Faya
# Retieving Results for 214| Laurel
# Retieving Results for 215| Bodden Town
# Retieving Results for 216| Serabu
# Retieving Results for 217| Santiago
# Retieving Results for 218| Kalmunai
# Retieving Results for 219| Prieska
# Retieving Results for 220| Samarai
# Retieving Results for 221| Bengkulu
# Retieving Results for 222| Whyalla
# Retieving Results for 223| Padang
# Retieving Results for 224| Havøysund
# Retieving Results for 225| Erzin
# Retieving Results for 226| Kenai
# Retieving Results for 227| Klaksvík
# Retieving Results for 228| Grand Gaube
# Retieving Results for 229| Ust'-Ilimsk
# Retieving Results for 230| Honiara
# Retieving Results for 231| Nago
# Retieving Results for 232| College
# Retieving Results for 233| Mardin
# Retieving Results for 234| Salme
# Retieving Results for 235| Christchurch
# Retieving Results for 236| Dali
# Retieving Results for 237| Araranguá
# Retieving Results for 238| Freeport
# Retieving Results for 239| Westerland
# Retieving Results for 240| Tomatlán
# Retieving Results for 241| Little Rock
# Retieving Results for 242| Nanyang
# City not found! Next...
# Retieving Results for 243| Esperance
# Retieving Results for 244| Witu
# Retieving Results for 245| Tarko-Sale
# Retieving Results for 246| Hervey Bay
# Retieving Results for 247| Adolfo López Mateos
# Retieving Results for 248| Caravelas
# Retieving Results for 249| Doha
# Retieving Results for 250| Kavieng
# Retieving Results for 251| Cumberland
# Retieving Results for 252| Bani Walid
# Retieving Results for 253| Saint George
# Retieving Results for 254| Maragogi
# Retieving Results for 255| Kutum
# Retieving Results for 256| Kruisfontein
# Retieving Results for 257| Bealanana
# Retieving Results for 258| Waipawa
# Retieving Results for 259| Zhanakorgan
# Retieving Results for 260| Moyale
# Retieving Results for 261| Nouadhibou
# Retieving Results for 262| Adigeni
# Retieving Results for 263| Clyde River
# Retieving Results for 264| Konstantinovka
# Retieving Results for 265| Port Hueneme
# Retieving Results for 266| Cabo San Lucas
# Retieving Results for 267| Marabá
# Retieving Results for 268| Castro
# Retieving Results for 269| Atbasar
# Retieving Results for 270| Kushmurun
# Retieving Results for 271| Lebu
# Retieving Results for 272| Camacha
# Retieving Results for 273| Fomboni
# City not found! Next...
# Retieving Results for 274| Tual
# Retieving Results for 275| Hanko
# Retieving Results for 276| Soller
# Retieving Results for 277| Yeppoon
# Retieving Results for 278| Alugan
# City not found! Next...
# Retieving Results for 279| Orlik
# Retieving Results for 280| Bangolo
# Retieving Results for 281| Karaman Province
# Retieving Results for 282| Zambezi
# Retieving Results for 283| San Patricio
# Retieving Results for 284| Olafsvik
# Retieving Results for 285| Los Llanos de Aridane
# City not found! Next...
# Retieving Results for 286| Xai-Xai
# Retieving Results for 287| Fortuna
# Retieving Results for 288| Tazovsky
# Retieving Results for 289| Krasnyy Yar
# Retieving Results for 290| Port Hedland
# Retieving Results for 291| Shetpe
# Retieving Results for 292| Agutaya
# Retieving Results for 293| Boyuibe
# Retieving Results for 294| Huarmey
# Retieving Results for 295| Yantal'
# Retieving Results for 296| Paamiut
# Retieving Results for 297| Tshikapa
# Retieving Results for 298| Totness
# Retieving Results for 299| Lac du Bonnet
# Retieving Results for 300| Aldan
# Retieving Results for 301| Alice Springs
# Retieving Results for 302| Maricá
# Retieving Results for 303| Jalu
# Retieving Results for 304| Mata
# Retieving Results for 305| Pemba
# Retieving Results for 306| Arvika
# Retieving Results for 307| Wittmund
# Retieving Results for 308| Bairiki Village
# Retieving Results for 309| Kitimat
# Retieving Results for 310| Razdol'noye
# Retieving Results for 311| Laoag
# Retieving Results for 312| Galeana
# Retieving Results for 313| Province of Mantua
# City not found! Next...
# Retieving Results for 314| Daşoguz
# Retieving Results for 315| Mahibadhoo
# Retieving Results for 316| Maputo
# Retieving Results for 317| Agboville
# Retieving Results for 318| Rocha
# Retieving Results for 319| Yārāda
# Retieving Results for 320| Luganville
# Retieving Results for 321| Cristalina
# Retieving Results for 322| El Chol
# City not found! Next...
# Retieving Results for 323| Nālūt
# City not found! Next...
# Retieving Results for 324| Sur
# Retieving Results for 325| Kalemie
# Retieving Results for 326| Smithers
# Retieving Results for 327| Panguna
# Retieving Results for 328| Coyhaique
# Retieving Results for 329| Tezu
# Retieving Results for 330| Karpogory
# Retieving Results for 331| Três Passos
# Retieving Results for 332| Krasnovishersk
# Retieving Results for 333| Ust-Maya
# Retieving Results for 334| Nova Odesa
# Retieving Results for 335| Talcahuano
# Retieving Results for 336| Sitka
# City not found! Next...
# Retieving Results for 337| Kapiri Mposhi
# Retieving Results for 338| Edd
# Retieving Results for 339| Makarov
# Retieving Results for 340| Cururupu
# City not found! Next...
# Retieving Results for 341| Mimongo
# Retieving Results for 342| Camacupa
# Retieving Results for 343| Ixtapa
# Retieving Results for 344| Hambantota
# Retieving Results for 345| Orange Cove
# Retieving Results for 346| Boa Vista
# Retieving Results for 347| Polunochnoye
# Retieving Results for 348| Seminole
# Retieving Results for 349| Necochea
# Retieving Results for 350| Quatre Cocos
# Retieving Results for 351| Sorong
# Retieving Results for 352| Canchungo
# Retieving Results for 353| Sørland
# Retieving Results for 354| Cayenne
# Retieving Results for 355| Santiago del Estero
# Retieving Results for 356| Alvarado
# Retieving Results for 357| Turka
# Retieving Results for 358| Matane
# Retieving Results for 359| Shimoda
# Retieving Results for 360| Undory
# Retieving Results for 361| Hamilton
# Retieving Results for 362| Marzuq
# Retieving Results for 363| Xique-Xique
# Retieving Results for 364| Frankenberg
# Retieving Results for 365| Fort Nelson
# Retieving Results for 366| Souillac
# Retieving Results for 367| Grindavik
# Retieving Results for 368| Salalah
# City not found! Next...
# Retieving Results for 369| Okhotsk
# Retieving Results for 370| Sosnovka
# Retieving Results for 371| Geraldton
# Retieving Results for 372| Tingo María
# Retieving Results for 373| Bacolod City
# Retieving Results for 374| Manzhouli
# Retieving Results for 375| Shubarkuduk
# Retieving Results for 376| Zonguldak
# Retieving Results for 377| Victor Harbor
# City not found! Next...
# Retieving Results for 378| Abhā
# Retieving Results for 379| Korla
# City not found! Next...
# Retieving Results for 380| Kahului
# Retieving Results for 381| Fallon
# Retieving Results for 382| Zhezkazgan
# Retieving Results for 383| Port Hawkesbury
# Retieving Results for 384| Aksarka
# Retieving Results for 385| Iquitos
# Retieving Results for 386| Kpandu
# City not found! Next...
# City not found! Next...
# Retieving Results for 387| Isla Vista
# Retieving Results for 388| Hutang
# Retieving Results for 389| Anloga
# Retieving Results for 390| Selkirk
# Retieving Results for 391| Svetlaya
# Retieving Results for 392| Vila Velha
# Retieving Results for 393| Naze
# Retieving Results for 394| Oranjemund
# Retieving Results for 395| Kaitangata
# Retieving Results for 396| Buritama
# City not found! Next...
# Retieving Results for 397| Nemuro
# Retieving Results for 398| Pemangkat
# Retieving Results for 399| Sambava
# Retieving Results for 400| Barra de Tecoanapa
# Retieving Results for 401| Chara
# Retieving Results for 402| Qingquan
# Retieving Results for 403| Pierre
# Retieving Results for 404| Peterhead
# Retieving Results for 405| Pathein
# Retieving Results for 406| Takoradze
# Retieving Results for 407| Solok
# City not found! Next...
# Retieving Results for 408| Chokurdakh
# Retieving Results for 409| Monrovia
# Retieving Results for 410| Tura
# Retieving Results for 411| Barpeta
# Retieving Results for 412| Sistranda
# Retieving Results for 413| Laas
# Retieving Results for 414| Agadez
# Retieving Results for 415| Luanda
# Retieving Results for 416| Piaçabuçu
# Retieving Results for 417| Nador
# Retieving Results for 418| Champerico
# Retieving Results for 419| Assiut
# Retieving Results for 420| Belmonte
# Retieving Results for 421| Alyangula
# Retieving Results for 422| Sabha
# Retieving Results for 423| Katangli
# Retieving Results for 424| Alta Floresta
# Retieving Results for 425| Abu Samrah
# Retieving Results for 426| Açucena
# Retieving Results for 427| Lagunas
# Retieving Results for 428| Narasannapeta
# Retieving Results for 429| Lavrentiya
# Retieving Results for 430| Temir
# Retieving Results for 431| Pitimbu
# Retieving Results for 432| Dickinson
# Retieving Results for 433| Henties Bay
# Retieving Results for 434| Chul'man
# Retieving Results for 435| Vilhena
# Retieving Results for 436| Dondo
# Retieving Results for 437| Synya
# Retieving Results for 438| Biu
# Retieving Results for 439| Pangnirtung
# Retieving Results for 440| Chulym
# Retieving Results for 441| Port-Cartier
# Retieving Results for 442| Kendari
# Retieving Results for 443| San Fernando del Valle de Catamarca
# Retieving Results for 444| Bud
# Retieving Results for 445| Makakilo City
# Retieving Results for 446| Novyy Karachay
# Retieving Results for 447| Bulungu
# Retieving Results for 448| Belaya Gora
# Retieving Results for 449| Blairmore
# Retieving Results for 450| Union
# Retieving Results for 451| Asău
# Retieving Results for 452| Edmonds
# Retieving Results for 453| Yerbogachën
# Retieving Results for 454| Vardø
# Retieving Results for 455| Hirara
# Retieving Results for 456| Mount Gambier
# Retieving Results for 457| Serro
# Retieving Results for 458| Zhigansk
# Retieving Results for 459| Bautzen
# Retieving Results for 460| Nyazepetrovsk
# Retieving Results for 461| Zhireken
# Retieving Results for 462| Umm Kaddadah
# Retieving Results for 463| Husavik
# City not found! Next...
# Retieving Results for 464| Sinaloa
# Retieving Results for 465| Itaituba
# Retieving Results for 466| Sembakung
# Retieving Results for 467| Fort Morgan
# City not found! Next...
# Retieving Results for 468| Nerópolis
# Retieving Results for 469| Nelson Bay
# Retieving Results for 470| Port Lincoln
# Retieving Results for 471| Leer
# Retieving Results for 472| Zyryanka
# Retieving Results for 473| Vostok
# Retieving Results for 474| Talnakh
# Retieving Results for 475| Seabra
# Retieving Results for 476| Tiznit Province
# Retieving Results for 477| Voznesen'ye
# Retieving Results for 478| Novaya Mayna
# Retieving Results for 479| Port Hardy
# Retieving Results for 480| Suclayin
# Retieving Results for 481| Thinadhoo
# Retieving Results for 482| Shōbara
# Retieving Results for 483| Hasaki
# City not found! Next...
# Retieving Results for 484| Bay Roberts
# Retieving Results for 485| Polyarny
# Retieving Results for 486| Maniitsoq
# Retieving Results for 487| Manaquiri
# Retieving Results for 488| Guánica
# Retieving Results for 489| Puerto Carreño
# Retieving Results for 490| São João da Barra
# Retieving Results for 491| Kuril'sk
# Retieving Results for 492| Muros
# Retieving Results for 493| Neustadt an der Waldnaab
# Retieving Results for 494| Phayakkhaphum Phisai
# City not found! Next...
# Retieving Results for 495| Skibbereen
# Retieving Results for 496| Bonthe
# Retieving Results for 497| Siyabuswa
# City not found! Next...
# Retieving Results for 498| Colares
# Retieving Results for 499| Bubaque
# Retieving Results for 500| Kaeo
# Retieving Results for 501| Fairlie
# City not found! Next...
# Retieving Results for 502| Gulu
# City not found! Next...
# Retieving Results for 503| Bongandanga
# Retieving Results for 504| Mandalgovi
# Retieving Results for 505| Aquiraz
# Retieving Results for 506| Andenes
# Retieving Results for 507| Sulangan
# Retieving Results for 508| Bagdarin
# Retieving Results for 509| Nome
# Retieving Results for 510| Isfahan
# Retieving Results for 511| Grand-Santi
# City not found! Next...
# Retieving Results for 512| Sinnamary
# Retieving Results for 513| Chumphon
# Retieving Results for 514| Jiazi
# Retieving Results for 515| Jambusar
# Retieving Results for 516| Hailar
# Retieving Results for 517| Seymchan
# Retieving Results for 518| Otyniya
# Retieving Results for 519| Pandan
# Retieving Results for 520| Barga
# Retieving Results for 521| Ninotsminda
# Retieving Results for 522| Lerwick
# Retieving Results for 523| Santarém
# Retieving Results for 524| Bāndarban
# Retieving Results for 525| Yangi Marg`ilon
# Retieving Results for 526| Santa Helena de Goiás
# Retieving Results for 527| Aloja
# Retieving Results for 528| Qaqortoq
# Retieving Results for 529| Letka
# Retieving Results for 530| Mezen'
# City not found! Next...
# Retieving Results for 531| Marsh Harbour
# Retieving Results for 532| São Filipe
# Retieving Results for 533| Aktobe
# Retieving Results for 534| Haines Junction
# Retieving Results for 535| Iqaluit
# Retieving Results for 536| Priargunsk
# Retieving Results for 537| Acapulco de Juárez
# Retieving Results for 538| Snåase
# Retieving Results for 539| Puerto Escondido
# Retieving Results for 540| Tres Arroyos
# Retieving Results for 541| Melivoia
# City not found! Next...
# Retieving Results for 542| Porto Santo
# Retieving Results for 543| Ola
# Retieving Results for 544| Akçaabat
# Retieving Results for 545| Vădăstriţa
# Retieving Results for 546| Khāsh
# Retieving Results for 547| Loa Janan
# Retieving Results for 548| Khromtau
# Retieving Results for 549| Wakkanai
# Retieving Results for 550| Laguna
# Retieving Results for 551| Bhīnmāl
# Retieving Results for 552| Krasnosel'kup
# Retieving Results for 553| Isangel
# Retieving Results for 554| Rawson
# Retieving Results for 555| Jacareacanga
# Retieving Results for 556| High Level
# Retieving Results for 557| Comodoro Rivadavia
# Retieving Results for 558| Vilyuysk
# Retieving Results for 559| Vestmannaeyjar
# Retieving Results for 560| Taywarah
# Retieving Results for 561| Kadhan
# Retieving Results for 562| Boguchany
# Retieving Results for 563| Estelle
# Retieving Results for 564| Sofiyivka
# Retieving Results for 565| Culebra
# Retieving Results for 566| La Orilla
# Retieving Results for 567| Baie-Comeau
# Retieving Results for 568| Dhārchula
# Retieving Results for 569| Imbituba
# Retieving Results for 570| Kungurtug
# Retieving Results for 571| Tiarei
# Retieving Results for 572| Pacific Grove
# Retieving Results for 573| Envira
# City not found! Next...
# Retieving Results for 574| Menongue
# Retieving Results for 575| Preobrazheniye
# Retieving Results for 576| Esqueda
# Retieving Results for 577| Ereymentau
# Retieving Results for 578| Moundou
# Retieving Results for 579| Provideniya
# Retieving Results for 580| Tabory
# Retieving Results for 581| Golden
# Retieving Results for 582| Kysyl-Syr
# ----------------------------
# Processing Complete

# %%
#Storing data and create DataFrame to display.

weather_store = {"Country": country_name, "City": cities_name, "Latitude": latitude, "Longitude": longitude,
                "Max Temperature": max_temp, "Humidity": humidity, "Wind Speed": wind_speed, "Cloudiness": cloudiness, 
                "Date":date}
weather_data = pd.DataFrame(weather_store)
weather_data.head()
# Out:
#   Country     City  Latitude  Longitude  Max Temperature  Humidity  \
# 0      RU     Mago   53.2514   140.1822           294.49        49
# 1      US     Hilo   19.7297  -155.0900           301.08        85
# 2      PF   Faanui  -16.4833  -151.7500           299.21        75
# 3      PF   Atuona   -9.8000  -139.0333           298.49        78
# 4      RE  Le Port  -20.9373    55.2919           294.13        80
#
#    Wind Speed  Cloudiness        Date
# 0        2.42           6  1630466824
# 1        2.57          90  1630466261
# 2        8.00           3  1630466343
# 3        7.66          23  1630466255
# 4        2.17          61  1630466826

# %%
pd.DataFrame(weather_data.describe())
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Wind Speed  \
# count  581.000000  581.000000       581.000000  581.000000  581.000000
# mean    21.903049   17.870837       292.677573   72.321859    3.078382
# std     33.089727   88.567146         7.482849   19.910525    2.193214
# min    -54.800000 -175.200000       272.130000    7.000000    0.000000
# 25%     -5.666700  -56.327500       287.100000   62.000000    1.440000
# 50%     26.588100   22.747400       293.950000   77.000000    2.570000
# 75%     50.250300   97.453100       298.580000   87.000000    4.170000
# max     78.218600  179.316700       308.360000  100.000000   11.310000
#
#        Cloudiness          Date
# count  581.000000  5.810000e+02
# mean    55.540448  1.630467e+09
# std     38.923893  2.648901e+02
# min      0.000000  1.630466e+09
# 25%     15.000000  1.630467e+09
# 50%     63.000000  1.630467e+09
# 75%     97.000000  1.630467e+09
# max    100.000000  1.630467e+09

# %%
#Save data to CSV
weather_data.to_csv("../weather_data.csv")

# %%
#Generate Scatter Plot for Latitude vs. Max Temperature.

plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], facecolors ="lightskyblue",
            marker = "o", edgecolor = "black")

plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Latitude vs. Max Temperature (09/01/2020)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()
plt.show()

plt.savefig("../data_images/Latitude_Max_Temperature.png")

# %%
#Generate Scatter Plot for Latitude vs. Humidity.

plt.scatter(weather_data["Latitude"], weather_data["Humidity"], facecolors ="orange",
            marker = "o", edgecolor = "red")

plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs. Humidity (09/01/2020)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()
plt.show()

plt.savefig("../data_images/Latitude_vs_Humidity.png")

# %%
#Generate Scatter Plot for Latitude vs. Cloudiness.

plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], facecolors ="pink",
            marker = "o", edgecolor = "grey")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs. Cloudiness (09/01/2020)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()
plt.show()

plt.savefig("../data_images/Latitude_vs_Cloudiness")

# %%
#Generate Scatter Plot vs. Wind Speed.

plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], facecolors ="lime",
            marker = "o", edgecolor = "orange")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs. Wind Speed (09/01/2020)")
plt.minorticks_on()
plt.grid(which="major", linestyle="-")
plt.grid(which="minor", linestyle=":")
plt.tight_layout()
plt.show()

plt.savefig("../data_images/Latitude_vs_WindSpeed.png")
